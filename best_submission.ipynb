# %%
# import normal libraries
import pandas as pd
import numpy as np

# %%
# import datasets
test_data = pd.read_parquet('/kaggle/input/volatility-smile-prediction/test_data.parquet') # add your test data file path
train_data = pd.read_parquet('/kaggle/input/volatility-smile-prediction/train_data.parquet') # add your train data file path
sample_data = pd.read_csv('/kaggle/input/volatility-smile-prediction/sample_submission.csv') # add your sample submission file path

# %%
# Convert data types to float32 for memory efficiency
test_data = test_data.astype('float32')

# %%
# Select predictors: X0 to X41 + underlying + timestamp
predictor_cols = [f"X{i}" for i in range(42)] + ["underlying"]
predictors = test_data[predictor_cols]

# Columns to impute (those with missing values)
iv_cols = test_data.columns[test_data.isnull().any()].tolist()

# Combine predictors and targets
impute_df = pd.concat([predictors, test_data[iv_cols]], axis=1)

# %%
# Display the first few rows of the impute_df DataFrame
impute_df.head()
# Out:
#             X0        X1        X2        X3             X4             X5  \
# 0  -2377420.00 -0.066961 -0.064562 -0.068452   23078.869141  117442.710938
# 1   6703629.00  0.030899 -0.031677 -0.033302   35119.902344 -153269.531250
# 2   2245442.25 -0.066279 -0.162606 -0.233426  -77723.031250   26958.333984
# 3 -17185772.00 -0.046657 -0.497496 -0.321425  227847.546875 -114322.914062
# 4   7473684.00 -0.440429  0.554007 -0.319750  481455.718750    9713.541992
#
#              X6   X7        X8   X9  ...  put_iv_24600  put_iv_24700  \
# 0 -5.593598e+04 -0.0 -0.001486  0.0  ...      0.232334           NaN
# 1 -1.084932e+05  0.0  0.002381 -0.0  ...           NaN      0.228209
# 2  4.740967e+05  0.0  0.000682 -0.0  ...      0.194612      0.188052
# 3  1.308353e+05  0.0 -0.000204  0.0  ...           NaN      0.166394
# 4  1.064944e+06  0.0  0.000594 -0.0  ...           NaN           NaN
#
#    put_iv_24800  put_iv_24900  put_iv_25000  put_iv_25100  put_iv_25200  \
# 0           NaN      0.227301      0.234169           NaN      0.250422
# 1           NaN           NaN           NaN      0.249402           NaN
# 2           NaN           NaN      0.181346           NaN      0.190750
# 3      0.161561           NaN           NaN      0.172032           NaN
# 4           NaN      0.177920           NaN      0.176000           NaN
#
#    put_iv_25300  put_iv_25400  put_iv_25500
# 0           NaN           NaN      0.282229
# 1           NaN           NaN           NaN
# 2           NaN           NaN           NaN
# 3           NaN           NaN      0.206107
# 4           NaN      0.182314           NaN
#
# [5 rows x 95 columns]

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.ensemble import ExtraTreesRegressor

# Define the Extra Trees Regressor with specific parameters
reg_et = ExtraTreesRegressor(
    n_estimators=800,
    max_depth=35,
    max_features=0.2,
    bootstrap=False,
    criterion='squared_error',
    min_samples_leaf=2,
    random_state=0,
    n_jobs=-1,
    warm_start=False
)

# Initialize the Iterative Imputer with the Extra Trees Regressor
imputer_et = IterativeImputer(
    estimator=reg_et,
    max_iter=25,
    tol=0,
    verbose=2,
    random_state=0,
    skip_complete=True,
    imputation_order='roman'
)

# Run imputation
final = imputer_et.fit_transform(impute_df)
# Out:
# [IterativeImputer] Completing matrix with shape (12065, 95)
# [IterativeImputer] Ending imputation round 1/25, elapsed time 72.64
# [IterativeImputer] Change: 2.1457180976867676, scaled tolerance: 0.0
# [IterativeImputer] Ending imputation round 2/25, elapsed time 144.98
# [IterativeImputer] Change: 0.09855930507183075, scaled tolerance: 0.0
# [IterativeImputer] Ending imputation round 3/25, elapsed time 218.02
# [IterativeImputer] Change: 0.03522367775440216, scaled tolerance: 0.0
# [IterativeImputer] Ending imputation round 4/25, elapsed time 290.97
# [IterativeImputer] Change: 0.028398677706718445, scaled tolerance: 0.0
# [IterativeImputer] Ending imputation round 5/25, elapsed time 364.67
# [IterativeImputer] Change: 0.02082820236682892, scaled tolerance: 0.0
# [IterativeImputer] Ending imputation round 6/25, elapsed time 439.01
# [IterativeImputer] Change: 0.016025185585021973, scaled tolerance: 0.0
# [IterativeImputer] Ending imputation round 7/25, elapsed time 513.19
# [IterativeImputer] Change: 0.012588709592819214, scaled tolerance: 0.0
# [IterativeImputer] Ending imputation round 8/25, elapsed time 587.49
# [IterativeImputer] Change: 0.009177148342132568, scaled tolerance: 0.0
# [IterativeImputer] Ending imputation round 9/25, elapsed time 662.89
# [IterativeImputer] Change: 0.007584095001220703, scaled tolerance: 0.0
# [IterativeImputer] Ending imputation round 10/25, elapsed time 738.33
# [IterativeImputer] Change: 0.008165046572685242, scaled tolerance: 0.0
# [IterativeImputer] Ending imputation round 11/25, elapsed time 814.28
# [IterativeImputer] Change: 0.00793999433517456, scaled tolerance: 0.0
# [IterativeImputer] Ending imputation round 12/25, elapsed time 889.57
# [IterativeImputer] Change: 0.006625756621360779, scaled tolerance: 0.0
# [IterativeImputer] Ending imputation round 13/25, elapsed time 966.14
# [IterativeImputer] Change: 0.005013942718505859, scaled tolerance: 0.0
# [IterativeImputer] Ending imputation round 14/25, elapsed time 1042.66
# [IterativeImputer] Change: 0.005570545792579651, scaled tolerance: 0.0
# [IterativeImputer] Ending imputation round 15/25, elapsed time 1118.67
# [IterativeImputer] Change: 0.006090372800827026, scaled tolerance: 0.0
# [IterativeImputer] Ending imputation round 16/25, elapsed time 1195.46
# [IterativeImputer] Change: 0.005293041467666626, scaled tolerance: 0.0
# [IterativeImputer] Ending imputation round 17/25, elapsed time 1272.06
# [IterativeImputer] Change: 0.005367249250411987, scaled tolerance: 0.0
# [IterativeImputer] Ending imputation round 18/25, elapsed time 1348.73
# [IterativeImputer] Change: 0.006623014807701111, scaled tolerance: 0.0
# [IterativeImputer] Ending imputation round 19/25, elapsed time 1425.45
# [IterativeImputer] Change: 0.005356982350349426, scaled tolerance: 0.0
# [IterativeImputer] Ending imputation round 20/25, elapsed time 1502.76
# [IterativeImputer] Change: 0.005173027515411377, scaled tolerance: 0.0
# [IterativeImputer] Ending imputation round 21/25, elapsed time 1580.20
# [IterativeImputer] Change: 0.005848631262779236, scaled tolerance: 0.0
# [IterativeImputer] Ending imputation round 22/25, elapsed time 1658.46
# [IterativeImputer] Change: 0.007653102278709412, scaled tolerance: 0.0
# [IterativeImputer] Ending imputation round 23/25, elapsed time 1736.98
# [IterativeImputer] Change: 0.006730109453201294, scaled tolerance: 0.0
# [IterativeImputer] Ending imputation round 24/25, elapsed time 1815.36
# [IterativeImputer] Change: 0.005391702055931091, scaled tolerance: 0.0
# [IterativeImputer] Ending imputation round 25/25, elapsed time 1893.70
# [IterativeImputer] Change: 0.005461707711219788, scaled tolerance: 0.0
# /usr/local/lib/python3.10/site-packages/sklearn/impute/_iterative.py:895: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(

# %%
# Convert the result back to a DataFrame with the same columns as impute_df
final = pd.DataFrame(final, columns=impute_df.columns)

# Display the first few rows of the final DataFrame
final.head()
# Out:
#             X0        X1        X2        X3             X4             X5  \
# 0  -2377420.00 -0.066961 -0.064562 -0.068452   23078.869141  117442.710938
# 1   6703629.00  0.030899 -0.031677 -0.033302   35119.902344 -153269.531250
# 2   2245442.25 -0.066279 -0.162606 -0.233426  -77723.031250   26958.333984
# 3 -17185772.00 -0.046657 -0.497496 -0.321425  227847.546875 -114322.914062
# 4   7473684.00 -0.440429  0.554007 -0.319750  481455.718750    9713.541992
#
#              X6   X7        X8   X9  ...  put_iv_24600  put_iv_24700  \
# 0 -5.593598e+04 -0.0 -0.001486  0.0  ...      0.232334      0.226131
# 1 -1.084932e+05  0.0  0.002381 -0.0  ...      0.234148      0.228209
# 2  4.740967e+05  0.0  0.000682 -0.0  ...      0.194612      0.188052
# 3  1.308353e+05  0.0 -0.000204  0.0  ...      0.173742      0.166394
# 4  1.064944e+06  0.0  0.000594 -0.0  ...      0.192943      0.186458
#
#    put_iv_24800  put_iv_24900  put_iv_25000  put_iv_25100  put_iv_25200  \
# 0      0.222216      0.227301      0.234169      0.244403      0.250422
# 1      0.224931      0.230033      0.239004      0.249402      0.258144
# 2      0.183017      0.180678      0.181346      0.185132      0.190750
# 3      0.161561      0.160448      0.164596      0.172032      0.181169
# 4      0.181847      0.177920      0.175750      0.176000      0.177532
#
#    put_iv_25300  put_iv_25400  put_iv_25500
# 0      0.258141      0.273116      0.282229
# 1      0.264064      0.271621      0.284078
# 2      0.196855      0.204597      0.212107
# 3      0.189764      0.197595      0.206107
# 4      0.178832      0.182314      0.186403
#
# [5 rows x 95 columns]

# %%
# Prepare the final DataFrame for submission
col = list(final.columns[0:43])

# Drop the first 43 columns (X0 to X42 + underlying) and keep the timestamp
df = final.drop(columns = col , axis = 1)

# Convert the data types of the final DataFrame to float64 for consistency
df = df.astype('float64')

# Add timestamp in final submission
df = pd.concat([test_data['timestamp'] , df] , axis =1)

# Change timestamp float32 -> int
df['timestamp'] = df['timestamp'].astype('int')

# Display the shape of the final DataFrame
print("Final DataFrame shape:", df.shape)

# Display the first few rows of the final DataFrame
df.head()
# Out:
# Final DataFrame shape: (12065, 53)
#    timestamp  call_iv_24000  call_iv_24100  call_iv_24200  call_iv_24300  \
# 0          0       0.280939       0.267904       0.257148       0.250008
# 1          1       0.270276       0.268842       0.258893       0.250230
# 2          2       0.256432       0.251731       0.236650       0.224854
# 3          3       0.241888       0.230190       0.220505       0.208795
# 4          4       0.235328       0.230086       0.222983       0.214126
#
#    call_iv_24400  call_iv_24500  call_iv_24600  call_iv_24700  call_iv_24800  \
# 0       0.242149       0.238095       0.232439       0.226047       0.222997
# 1       0.244276       0.238992       0.233548       0.227940       0.225056
# 2       0.214869       0.204580       0.194604       0.188210       0.183200
# 3       0.198602       0.186190       0.174353       0.166617       0.161614
# 4       0.206140       0.199226       0.192603       0.186454       0.181901
#
#    ...  put_iv_24600  put_iv_24700  put_iv_24800  put_iv_24900  put_iv_25000  \
# 0  ...      0.232334      0.226131      0.222216      0.227301      0.234169
# 1  ...      0.234148      0.228209      0.224931      0.230033      0.239004
# 2  ...      0.194612      0.188052      0.183017      0.180678      0.181346
# 3  ...      0.173742      0.166394      0.161561      0.160448      0.164596
# 4  ...      0.192943      0.186458      0.181847      0.177920      0.175750
#
#    put_iv_25100  put_iv_25200  put_iv_25300  put_iv_25400  put_iv_25500
# 0      0.244403      0.250422      0.258141      0.273116      0.282229
# 1      0.249402      0.258144      0.264064      0.271621      0.284078
# 2      0.185132      0.190750      0.196855      0.204597      0.212107
# 3      0.172032      0.181169      0.189764      0.197595      0.206107
# 4      0.176000      0.177532      0.178832      0.182314      0.186403
#
# [5 rows x 53 columns]

# %%
# Save the final DataFrame to a CSV file for submission
df.to_csv('submission.csv', index=False)
print("Done...")
# Out:
# Done...
